# %%
#pip install beautifulsoup4
#pip install requests
import requests as rq
import bs4

# %%
res=rq.get("https://es.wikipedia.org/wiki/Inteligencia_artificial")
soup= bs4.BeautifulSoup(res.text,'html.parser')
x=soup.find_all('p')
text=' '
for i in range(len(x)):
    text += x[i].text.strip() + '\n'
    print(text)
# Out:
#  La inteligencia artificial (abreviado: IA), en el contexto de las ciencias de la computación, es una disciplina y un conjunto de capacidades cognoscitivas e intelectuales expresadas por sistemas informáticos o combinaciones de algoritmos cuyo propósito es la creación de máquinas que imiten la inteligencia humana para realizar tareas, y que pueden mejorar conforme recopilen información.[1]​[2]​ Se hizo presente poco después de la Segunda Guerra Mundial con el desarrollo de la «prueba de Turing», mientras que la locución fue acuñada en 1956 por el informático John McCarthy en la Conferencia de Dartmouth.
#
# ...

# %%
#pip install tweepy
import tweepy
from tweepy import OAuthHandler
n_tweets=10
my_location="19.61487525669009, -98.99734007185609"
my_keyword= "league"
my_tweets = []
my_custumer_key="d4KmTfkoEs28mFsp3tR4u7eaC"
my_custumer_secret="y8SDMC5XZrfwcJug51RZFVmsBxx8ASw9jN6U7HEK1qWUETsLu0"
my_access_token="1529375139946708992-R8WbvJnO0XJKwVYAWRQe5O9Us1zXlG"
my_access_secret="hoAGJrDJlDG74HmFjVDR4eTSoYeyzwRexpV36UEJ2qeEq"
Auth =OAuthHandler(my_custumer_key,my_custumer_secret)
Auth.set_access_token(my_access_token,my_access_secret)
api=tweepy.API(Auth,timeout=10)
for status in tweepy.Cursor(
    api.search_tweets,
    q=my_keyword + " -filter:retweets",
    lang="en",result_type= "recent",
    geocode= my_location
    ).items(n_tweets):
    my_tweets.append(status.text)
# Out:
# c:\Users\oscar\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:300: SyntaxWarning: invalid escape sequence '\['
#   """home_timeline(*, count, since_id, max_id, trim_user, \
# c:\Users\oscar\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:340: SyntaxWarning: invalid escape sequence '\['
#   """mentions_timeline(*, count, since_id, max_id, trim_user, \
# c:\Users\oscar\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:375: SyntaxWarning: invalid escape sequence '\['
#   """user_timeline(*, user_id, screen_name, since_id, count, max_id, \
# c:\Users\oscar\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:425: SyntaxWarning: invalid escape sequence '\['
#   """get_favorites(*, user_id, screen_name, count, since_id, max_id, \
# c:\Users\oscar\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:466: SyntaxWarning: invalid escape sequence '\['
# ...

# %%
import tweepy
from tweepy import OAuthHandler

my_consumer_key = "-"
my_consumer_secret = "-"
my_access_token = "-"
my_access_secret = "-"

my_keyword = "hola"  
my_location = "37.7749,-122.4194,50km"  
n_tweets = 10  
my_tweets = []  

# Initialize the token.
Auth = OAuthHandler(my_consumer_key, my_consumer_secret)
Auth.set_access_token(my_access_token, my_access_secret)

api = tweepy.API(Auth, timeout=10)  # Timeout after 10 seconds

for status in tweepy.Cursor(
    api.search_tweets, 
    q=my_keyword + " -filter:retweets",
    lang="en", 
    result_type="recent", 
    geocode=my_location
).items(n_tweets):

    my_tweets.append(status.text)
# Out:
# c:\Users\oscar\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:300: SyntaxWarning: invalid escape sequence '\['
#   """home_timeline(*, count, since_id, max_id, trim_user, \
# c:\Users\oscar\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:340: SyntaxWarning: invalid escape sequence '\['
#   """mentions_timeline(*, count, since_id, max_id, trim_user, \
# c:\Users\oscar\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:375: SyntaxWarning: invalid escape sequence '\['
#   """user_timeline(*, user_id, screen_name, since_id, count, max_id, \
# c:\Users\oscar\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:425: SyntaxWarning: invalid escape sequence '\['
#   """get_favorites(*, user_id, screen_name, count, since_id, max_id, \
# c:\Users\oscar\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:466: SyntaxWarning: invalid escape sequence '\['
# ...
